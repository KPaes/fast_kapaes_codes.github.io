# %% [markdown]
# # Mapear automaticamente as tabelas do Postgres com Python

# %% [markdown]
# Código que cria um dicionário de dados das tabelas existentes do schema público de uma database fictícia

# %% [markdown]
#  *Importações dos módulos*

# %%
import psycopg2
from psycopg2.extensions import AsIs

import functools 
import operator 

import json

# %% [markdown]
# *Definição das variáveis para acesso ao banco de dados*

# %%
pg_dbname = "dvdrental"  # nome database 
pg_username = "postgres" # nome do usuário
pg_password = "abc123"   # senha do usuário 

conn = psycopg2.connect(dbname=pg_dbname, user=pg_username, password=pg_password)
cur = conn.cursor() # Objeto de conexão

# %% [markdown]
# *Função que define as tabelas existentes no schema public da base de dados informada anteriormente*

# %%
def tables_names(cur):
    cur.execute("SELECT  table_name from information_schema.tables WHERE table_schema='public' ORDER BY table_name")
    table_names = cur.fetchall()
    
    return table_names

# %% [markdown]
# *Função que imprime as descrições das tabelas do schema public*

# %%
def tables_descriptions(cur):

    cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")
    for table in cur.fetchall(): 
        table = table[0]
        cur.execute("SELECT * FROM %s LIMIT 0",    [AsIs(table)])
        print(cur.description, "\n")

# %%
#tables_descriptions(cur)

# %% [markdown]
# *Função que converte lista de tuplas em lista de string*

# %%
def convertTuple(tup): 
    str =  functools.reduce(operator.add, (tup))
    return str

# %% [markdown]
# ### Função que define as descrições das tabelas com nome, tipo de dado e tamanho em formato quase legível

# %%
def tables_readable_description(cur, table_list):

    # Dicionário com os tipos de dados do Postgres    
    cur.execute("SELECT oid, typname FROM pg_catalog.pg_type")
    type_mappings = {
        int(oid): typname
        for oid, typname in cur.fetchall()
    }    


    readable_description = {}
    for table in table_list:
        cur.execute("SELECT * FROM %s LIMIT 0", [AsIs(table)])
        readable_description[table] = dict(
            columns=[
                dict(
                    name=col.name,
                    type=type_mappings[col.type_code],
                    length=col.internal_size
                )
                for col in cur.description
            ]
        )
    
    return readable_description

# %% [markdown]
# *Função que adiciona a quantidade de linhas das tabelas*

# %%
def add_rows_total(cur, readable_description):
    for table in readable_description.keys():
        cur.execute("SELECT COUNT(*) FROM %s", [AsIs(table)])
        readable_description[table]["total"] = cur.fetchone()[0]
    
    return readable_description

# %% [markdown]
# ## Chamada das funções

# %%
table_names = tables_names(cur) # Definimos uma lista com os nomes das tabelas

# %%
#print("Quantidade de tabelas: ", len(table_names))
 
#for line in table_names:
#    print(line)

# %%
table_list = convertTuple(table_names) # Convertemos a lista de tuplas para uma lista de strings

readable_description = tables_readable_description(cur, table_list) # Criamos um dicionário de dados das tabelas

print(readable_description)
# Out:
# {'account': {'columns': [{'name': 'user_id', 'type': 'int4', 'length': 4}, {'name': 'username', 'type': 'varchar', 'length': 50}, {'name': 'password', 'type': 'varchar', 'length': 50}, {'name': 'email', 'type': 'varchar', 'length': 300}, {'name': 'created_on', 'type': 'timestamp', 'length': 8}, {'name': 'last_login', 'type': 'timestamp', 'length': 8}]}, 'actor': {'columns': [{'name': 'actor_id', 'type': 'int4', 'length': 4}, {'name': 'first_name', 'type': 'varchar', 'length': 45}, {'name': 'last_name', 'type': 'varchar', 'length': 45}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'actor_info': {'columns': [{'name': 'actor_id', 'type': 'int4', 'length': 4}, {'name': 'first_name', 'type': 'varchar', 'length': 45}, {'name': 'last_name', 'type': 'varchar', 'length': 45}, {'name': 'film_info', 'type': 'text', 'length': -1}]}, 'address': {'columns': [{'name': 'address_id', 'type': 'int4', 'length': 4}, {'name': 'address', 'type': 'varchar', 'length': 50}, {'name': 'address2', 'type': 'varchar', 'length': 50}, {'name': 'district', 'type': 'varchar', 'length': 20}, {'name': 'city_id', 'type': 'int2', 'length': 2}, {'name': 'postal_code', 'type': 'varchar', 'length': 10}, {'name': 'phone', 'type': 'varchar', 'length': 20}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'category': {'columns': [{'name': 'category_id', 'type': 'int4', 'length': 4}, {'name': 'name', 'type': 'varchar', 'length': 25}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'city': {'columns': [{'name': 'city_id', 'type': 'int4', 'length': 4}, {'name': 'city', 'type': 'varchar', 'length': 50}, {'name': 'country_id', 'type': 'int2', 'length': 2}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'country': {'columns': [{'name': 'country_id', 'type': 'int4', 'length': 4}, {'name': 'country', 'type': 'varchar', 'length': 50}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'customer': {'columns': [{'name': 'customer_id', 'type': 'int4', 'length': 4}, {'name': 'store_id', 'type': 'int2', 'length': 2}, {'name': 'first_name', 'type': 'varchar', 'length': 45}, {'name': 'last_name', 'type': 'varchar', 'length': 45}, {'name': 'email', 'type': 'varchar', 'length': 50}, {'name': 'address_id', 'type': 'int2', 'length': 2}, {'name': 'activebool', 'type': 'bool', 'length': 1}, {'name': 'create_date', 'type': 'date', 'length': 4}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}, {'name': 'active', 'type': 'int4', 'length': 4}]}, 'customer_list': {'columns': [{'name': 'id', 'type': 'int4', 'length': 4}, {'name': 'name', 'type': 'text', 'length': -1}, {'name': 'address', 'type': 'varchar', 'length': 50}, {'name': 'zip code', 'type': 'varchar', 'length': 10}, {'name': 'phone', 'type': 'varchar', 'length': 20}, {'name': 'city', 'type': 'varchar', 'length': 50}, {'name': 'country', 'type': 'varchar', 'length': 50}, {'name': 'notes', 'type': 'text', 'length': -1}, {'name': 'sid', 'type': 'int2', 'length': 2}]}, 'film': {'columns': [{'name': 'film_id', 'type': 'int4', 'length': 4}, {'name': 'title', 'type': 'varchar', 'length': 255}, {'name': 'description', 'type': 'text', 'length': -1}, {'name': 'release_year', 'type': 'int4', 'length': 4}, {'name': 'language_id', 'type': 'int2', 'length': 2}, {'name': 'rental_duration', 'type': 'int2', 'length': 2}, {'name': 'rental_rate', 'type': 'numeric', 'length': 4}, {'name': 'length', 'type': 'int2', 'length': 2}, {'name': 'replacement_cost', 'type': 'numeric', 'length': 5}, {'name': 'rating', 'type': 'mpaa_rating', 'length': 4}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}, {'name': 'special_features', 'type': '_text', 'length': -1}, {'name': 'fulltext', 'type': 'tsvector', 'length': -1}]}, 'film_actor': {'columns': [{'name': 'actor_id', 'type': 'int2', 'length': 2}, {'name': 'film_id', 'type': 'int2', 'length': 2}, {'name': 'last_update', 'type': 'timestamp', 'length': 8}]}, 'film_category': {'columns': [{'name': 'film_id', 'type': 'int2', 'length': 2}, {' ...

# %%
add_rows_total(cur, readable_description) # Adiciona o total de linhas de cada tabela

json_str = json.dumps(readable_description, indent=2) # Converte o dicionário de dados para um formato legível em JSON 

print(json_str)
# Out:
# {
#   "account": {
#     "columns": [
#       {
#         "name": "user_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "username",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "password",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "email",
#         "type": "varchar",
#         "length": 300
#       },
#       {
#         "name": "created_on",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "last_login",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 0
#   },
#   "actor": {
#     "columns": [
#       {
#         "name": "actor_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "first_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "last_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 200
#   },
#   "actor_info": {
#     "columns": [
#       {
#         "name": "actor_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "first_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "last_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "film_info",
#         "type": "text",
#         "length": -1
#       }
#     ],
#     "total": 200
#   },
#   "address": {
#     "columns": [
#       {
#         "name": "address_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "address",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "address2",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "district",
#         "type": "varchar",
#         "length": 20
#       },
#       {
#         "name": "city_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "postal_code",
#         "type": "varchar",
#         "length": 10
#       },
#       {
#         "name": "phone",
#         "type": "varchar",
#         "length": 20
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 603
#   },
#   "category": {
#     "columns": [
#       {
#         "name": "category_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "name",
#         "type": "varchar",
#         "length": 25
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 16
#   },
#   "city": {
#     "columns": [
#       {
#         "name": "city_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "city",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "country_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 600
#   },
#   "country": {
#     "columns": [
#       {
#         "name": "country_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "country",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 109
#   },
#   "customer": {
#     "columns": [
#       {
#         "name": "customer_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "store_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "first_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "last_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "email",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "address_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "activebool",
#         "type": "bool",
#         "length": 1
#       },
#       {
#         "name": "create_date",
#         "type": "date",
#         "length": 4
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "active",
#         "type": "int4",
#         "length": 4
#       }
#     ],
#     "total": 599
#   },
#   "customer_list": {
#     "columns": [
#       {
#         "name": "id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "name",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "address",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "zip code",
#         "type": "varchar",
#         "length": 10
#       },
#       {
#         "name": "phone",
#         "type": "varchar",
#         "length": 20
#       },
#       {
#         "name": "city",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "country",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "notes",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "sid",
#         "type": "int2",
#         "length": 2
#       }
#     ],
#     "total": 599
#   },
#   "film": {
#     "columns": [
#       {
#         "name": "film_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "title",
#         "type": "varchar",
#         "length": 255
#       },
#       {
#         "name": "description",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "release_year",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "language_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "rental_duration",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "rental_rate",
#         "type": "numeric",
#         "length": 4
#       },
#       {
#         "name": "length",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "replacement_cost",
#         "type": "numeric",
#         "length": 5
#       },
#       {
#         "name": "rating",
#         "type": "mpaa_rating",
#         "length": 4
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "special_features",
#         "type": "_text",
#         "length": -1
#       },
#       {
#         "name": "fulltext",
#         "type": "tsvector",
#         "length": -1
#       }
#     ],
#     "total": 1000
#   },
#   "film_actor": {
#     "columns": [
#       {
#         "name": "actor_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "film_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 5462
#   },
#   "film_category": {
#     "columns": [
#       {
#         "name": "film_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "category_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 1000
#   },
#   "film_list": {
#     "columns": [
#       {
#         "name": "fid",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "title",
#         "type": "varchar",
#         "length": 255
#       },
#       {
#         "name": "description",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "category",
#         "type": "varchar",
#         "length": 25
#       },
#       {
#         "name": "price",
#         "type": "numeric",
#         "length": 4
#       },
#       {
#         "name": "length",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "rating",
#         "type": "mpaa_rating",
#         "length": 4
#       },
#       {
#         "name": "actors",
#         "type": "text",
#         "length": -1
#       }
#     ],
#     "total": 997
#   },
#   "inventory": {
#     "columns": [
#       {
#         "name": "inventory_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "film_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "store_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 4581
#   },
#   "language": {
#     "columns": [
#       {
#         "name": "language_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "name",
#         "type": "bpchar",
#         "length": 20
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 6
#   },
#   "nicer_but_slower_film_list": {
#     "columns": [
#       {
#         "name": "fid",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "title",
#         "type": "varchar",
#         "length": 255
#       },
#       {
#         "name": "description",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "category",
#         "type": "varchar",
#         "length": 25
#       },
#       {
#         "name": "price",
#         "type": "numeric",
#         "length": 4
#       },
#       {
#         "name": "length",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "rating",
#         "type": "mpaa_rating",
#         "length": 4
#       },
#       {
#         "name": "actors",
#         "type": "text",
#         "length": -1
#       }
#     ],
#     "total": 997
#   },
#   "payment": {
#     "columns": [
#       {
#         "name": "payment_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "customer_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "staff_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "rental_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "amount",
#         "type": "numeric",
#         "length": 5
#       },
#       {
#         "name": "payment_date",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 14596
#   },
#   "potential_leads": {
#     "columns": [
#       {
#         "name": "user_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "first_name",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "last_name",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "email",
#         "type": "varchar",
#         "length": 300
#       },
#       {
#         "name": "signup_date",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "minutes_spent",
#         "type": "int4",
#         "length": 4
#       }
#     ],
#     "total": 0
#   },
#   "rental": {
#     "columns": [
#       {
#         "name": "rental_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "rental_date",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "inventory_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "customer_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "return_date",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "staff_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 16044
#   },
#   "role": {
#     "columns": [
#       {
#         "name": "role_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "role_name",
#         "type": "varchar",
#         "length": 255
#       }
#     ],
#     "total": 0
#   },
#   "sales_by_film_category": {
#     "columns": [
#       {
#         "name": "category",
#         "type": "varchar",
#         "length": 25
#       },
#       {
#         "name": "total_sales",
#         "type": "numeric",
#         "length": -1
#       }
#     ],
#     "total": 16
#   },
#   "sales_by_store": {
#     "columns": [
#       {
#         "name": "store",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "manager",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "total_sales",
#         "type": "numeric",
#         "length": -1
#       }
#     ],
#     "total": 2
#   },
#   "staff": {
#     "columns": [
#       {
#         "name": "staff_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "first_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "last_name",
#         "type": "varchar",
#         "length": 45
#       },
#       {
#         "name": "address_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "email",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "store_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "active",
#         "type": "bool",
#         "length": 1
#       },
#       {
#         "name": "username",
#         "type": "varchar",
#         "length": 16
#       },
#       {
#         "name": "password",
#         "type": "varchar",
#         "length": 40
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       },
#       {
#         "name": "picture",
#         "type": "bytea",
#         "length": -1
#       }
#     ],
#     "total": 2
#   },
#   "staff_list": {
#     "columns": [
#       {
#         "name": "id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "name",
#         "type": "text",
#         "length": -1
#       },
#       {
#         "name": "address",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "zip code",
#         "type": "varchar",
#         "length": 10
#       },
#       {
#         "name": "phone",
#         "type": "varchar",
#         "length": 20
#       },
#       {
#         "name": "city",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "country",
#         "type": "varchar",
#         "length": 50
#       },
#       {
#         "name": "sid",
#         "type": "int2",
#         "length": 2
#       }
#     ],
#     "total": 2
#   },
#   "store": {
#     "columns": [
#       {
#         "name": "store_id",
#         "type": "int4",
#         "length": 4
#       },
#       {
#         "name": "manager_staff_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "address_id",
#         "type": "int2",
#         "length": 2
#       },
#       {
#         "name": "last_update",
#         "type": "timestamp",
#         "length": 8
#       }
#     ],
#     "total": 2
#   }
# }

# %%
conn.close() # Fechamos a conexão com o Postgres
